# %% [markdown]
# # 进阶：自动生成语气词
#
# 同济子豪兄 2024-6-12

# %% [markdown]
# ## 导入工具包

# %%
import torchaudio
import torch
from ChatTTS import ChatTTS
import soundfile
from IPython.display import Audio

# %% [markdown]
# ## 载入预训练模型

# %%
chat = ChatTTS.Chat()
chat.load_models(compile=False) # 设置为Flase获得更快速度，设置为True获得更佳效果
# Out:
# INFO:ChatTTS.ChatTTS.core:Load from cache: /home/featurize/.cache/huggingface/hub/models--2Noise--ChatTTS/snapshots/cc14302f34d7855eb3420d1fd48345012ff1460d
# INFO:ChatTTS.ChatTTS.core:use cuda:0
# INFO:ChatTTS.ChatTTS.core:vocos loaded.
# INFO:ChatTTS.ChatTTS.core:dvae loaded.
# INFO:ChatTTS.ChatTTS.core:gpt loaded.
# INFO:ChatTTS.ChatTTS.core:decoder loaded.
# INFO:ChatTTS.ChatTTS.core:tokenizer loaded.
# INFO:ChatTTS.ChatTTS.core:All initialized.

# %% [markdown]
# ## 原文

# %%
text = "So we found being competitive and collaborative was a huge way of staying motivated towards our goals, so one person to call when you fall off, one person who gets you back on then one person to actually do the activity with."

# %%
text = '三星堆遗址，位于四川省广汉市，被称为二十世纪人类最伟大的考古发现之一'

# %% [markdown]
# ## 自动生成语气词

# %%
refine_text = chat.infer(text, refine_text_only=True)
# Out:
# INFO:ChatTTS.ChatTTS.core:All initialized.
#  10%|█         | 40/384 [00:00<00:05, 59.09it/s]

# %%
refine_text
# Out:
# ['so [uv_break] we found being competitive and collaborative [uv_break] was a huge way [uv_break] of staying motivated towards our goals, [uv_break] so [uv_break] one person to call when you fall off, one person who gets you back on [uv_break] then one person to actually do the activity with.']

# %%
refine_text
# Out:
# ['三 星 堆 遗 址 [uv_break] ， 位 于 四 川 省 广 汉 市 ， 被 称 为 二 十 世 纪 人 类 [uv_break] 最 伟 大 的 考 古 发 现 之 一 [uv_break]']

# %% [markdown]
# > `refine_text_only=True`的作用：断句、自动添加停顿、转换阿拉伯数字等。

# %% [markdown]
# ## 语音合成模型推理

# %%
# 要生成语气词
wavs = chat.infer(refine_text)

# # 不要生成语气词
# wavs = chat.infer(text, skip_refine_text=True)
# Out:
# INFO:ChatTTS.ChatTTS.core:All initialized.
#  10%|█         | 40/384 [00:00<00:05, 58.99it/s]
#  16%|█▋        | 333/2048 [00:05<00:29, 58.68it/s]

# %% [markdown]
# ## 试听

# %%
Audio(wavs[0], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(wavs[0], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 导出保存为音频文件

# %%
torchaudio.save("output_c2.wav", torch.from_numpy(wavs[0]), 24000)
