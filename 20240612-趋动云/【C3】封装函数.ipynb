# %% [markdown]
# # 封装函数`zihao_tts.py`
#
# 同济子豪兄 2024-6-12

# %% [markdown]
# ## 导入函数

# %%
from zihao_tts import *
# Out:
# INFO:ChatTTS.ChatTTS.core:Load from cache: /root/.cache/huggingface/hub/models--2Noise--ChatTTS/snapshots/cc14302f34d7855eb3420d1fd48345012ff1460d
# INFO:ChatTTS.ChatTTS.core:use cuda:0
# INFO:ChatTTS.ChatTTS.core:vocos loaded.
# INFO:ChatTTS.ChatTTS.core:dvae loaded.
# INFO:ChatTTS.ChatTTS.core:gpt loaded.
# INFO:ChatTTS.ChatTTS.core:decoder loaded.
# INFO:ChatTTS.ChatTTS.core:tokenizer loaded.
# INFO:ChatTTS.ChatTTS.core:All initialized.

# %% [markdown]
# ## 调用函数

# %%
wavs = zihao_tts('我今天真的Feel Good，跑通了语音合成的开源项目，真的特别感谢子豪兄的代码教程！')
# Out:
# INFO:ChatTTS.ChatTTS.core:All initialized.
# WARNING:ChatTTS.ChatTTS.core:Invalid characters found! : {'！'}
#  11%|█▏        | 44/384 [00:02<00:17, 19.35it/s]
#  18%|█▊        | 368/2048 [00:03<00:18, 93.27it/s]

# %%
Audio(wavs[0], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wavs = zihao_tts('学人工智能的第一步，当然是Python编程')
# Out:
# INFO:ChatTTS.ChatTTS.core:All initialized.
#   5%|▍         | 19/384 [00:00<00:04, 88.90it/s]
#   7%|▋         | 139/2048 [00:01<00:20, 91.80it/s]

# %%
Audio(wavs[0], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 通过函数参数控制口语化、笑声、停顿程度

# %%
wavs = zihao_tts('在别人眼里 [uv_break] 你是[laugh]黑寡妇，[uv_break]在我这儿 [uv_break] 你就是 [uv_break] 吉祥物 [laugh]',oral=2, laugh=9, bk=3)
# Out:
# INFO:ChatTTS.ChatTTS.core:All initialized.
#   8%|▊         | 31/384 [00:00<00:03, 93.01it/s]
#  15%|█▍        | 302/2048 [00:03<00:18, 93.11it/s]

# %%
Audio(wavs[0], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
